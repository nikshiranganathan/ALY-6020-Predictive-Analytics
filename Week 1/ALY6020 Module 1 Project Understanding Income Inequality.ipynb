# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing CSV file
df_census = pd.read_csv("C:/Users/14086/Downloads/ALY 6020/adult-all.csv", header=0)

# %%
df_census.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital.gain    48842 non-null  int64
#  11  capital.loss    48842 non-null  int64
#  12  hours.per.week  48842 non-null  int64
#  13  native.country  48842 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df_census.shape
# Out:
# (48842, 15)

# %%
df_census.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             48842.0      38.643585      13.710510     17.0      28.0
# fnlwgt          48842.0  189664.134597  105604.025423  12285.0  117550.5
# education-num   48842.0      10.078089       2.570973      1.0       9.0
# capital.gain    48842.0    1079.067626    7452.019058      0.0       0.0
# capital.loss    48842.0      87.502314     403.004552      0.0       0.0
# hours.per.week  48842.0      40.422382      12.391444      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178144.5  237642.0  1490400.0
# education-num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0

# %%
df_census.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
df_census.drop('fnlwgt', axis=1, inplace=True)

# %%
df_census = df_census.drop_duplicates()
df_census
# Out:
#        age         workclass  education  education-num      marital-status  \
# 0       39         State-gov  Bachelors             13       Never-married
# 1       50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2       38           Private    HS-grad              9            Divorced
# 3       53           Private       11th              7  Married-civ-spouse
# 4       28           Private  Bachelors             13  Married-civ-spouse
# ...    ...               ...        ...            ...                 ...
# 48836   33           Private  Bachelors             13       Never-married
# 48837   39           Private  Bachelors             13            Divorced
# 48838   64                 ?    HS-grad              9             Widowed
# 48840   44           Private  Bachelors             13            Divorced
# 48841   35      Self-emp-inc  Bachelors             13  Married-civ-spouse
#
# ...

# %%
df_census.shape
# Out:
# (42468, 14)

# %%
df_census.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
(df_census == '?').sum()
# Out:
# age                  0
# workclass         2411
# education            0
# education-num        0
# marital-status       0
# occupation        2421
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     853
# income               0
# dtype: int64

# %%
df_census.replace('?',"Unknown", inplace=True)

# %%
df_census.isna().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df_census.head()
# Out:
#    age         workclass  education  education-num      marital-status  \
# 0   39         State-gov  Bachelors             13       Never-married
# 1   50  Self-emp-not-inc  Bachelors             13  Married-civ-spouse
# 2   38           Private    HS-grad              9            Divorced
# 3   53           Private       11th              7  Married-civ-spouse
# 4   28           Private  Bachelors             13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital.gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0             0              40  United-States  <=50K
# ...

# %%
def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = f"{corr_r:2.2f}".replace("0.", ".")
    ax = plt.gca()
    ax.set_axis_off()
    marker_size = abs(corr_r) * 10000
    ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
               vmin=-1, vmax=1, transform=ax.transAxes)
    font_size = abs(corr_r) * 80 + 10 
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)

sns.set(style='white', font_scale=1.6)
g = sns.PairGrid(df_census, aspect=1.4, diag_sharey=False)
g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'black'})
g.map_diag(sns.distplot, kde_kws={'color': 'black'})
g.map_upper(corrdot)

# %%
numeric_columns = ['age', 'education-num', 'capital.gain', 'capital.loss', 'hours.per.week']
plt.figure(figsize=(25, 15))

for i, column in enumerate(numeric_columns, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df_census[column], bins=30, kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

# %%
import plotly.graph_objects as go
income_distribution = df_census['income'].value_counts(normalize=True) * 100
fig = go.Figure()
fig.add_trace(go.Pie(
    labels=income_distribution.index,
    values=income_distribution,
    hole=0.6,
    showlegend=True,
    marker=dict(colors=['#79AF97FF', '#FFDC91FF']),
    hovertemplate="%{label} Income: %{value:.2f}%"))

fig.update_layout(
    title='Income Distribution',
    width=700)
# Out:
# <div>                            <div id="36364d62-eac8-49c6-847c-26a979284390" class="plotly-graph-div" style="height:525px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36364d62-eac8-49c6-847c-26a979284390")) {                    Plotly.newPlot(                        "36364d62-eac8-49c6-847c-26a979284390",                        [{"hole":0.6,"hovertemplate":"%{label} Income: %{value:.2f}%","labels":["<=50K",">50K"],"marker":{"colors":["#79AF97FF","#FFDC91FF"]},"showlegend":true,"values":[75.39794668927192,24.602053310728078],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9
# ...

# %%
sns.countplot(x=df_census['sex'], hue=df_census['income'], palette={"#F39B7FFF", "#938dd2"})
plt.title('Income of Different Genders', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16)
plt.show()

# %%
sns.histplot(data=df_census, x='age', hue='income', multiple='stack', bins=range(min(df_census['age']), max(df_census['age']) + 1, 1), edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Income vs Age')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
def label_encoding(df, columns):
    label_encoder = LabelEncoder()
    for col in columns:
        df[col] = label_encoder.fit_transform(df[col])
    return df

columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native.country', 'income']
df_census_copy = label_encoding(df_census.copy(), columns)

# %%
plt.figure(figsize=(20,15))
cmap = sns.color_palette("coolwarm", as_cmap=True)
ax = sns.heatmap(df_census_copy.corr(), annot=True, square=True, fmt='.2f', linecolor='black', cmap=cmap)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)
plt.title('Correlation between the variables')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = df_census_copy[['age', 'workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'sex', 'hours.per.week', 'native.country']]
y = df_census_copy['income']
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)
x.shape, y.shape
# Out:
# ((42468, 9), (42468,))

# %%
from sklearn.preprocessing import StandardScaler

st =  StandardScaler()
X_train = st.fit_transform(X_train)
X_test = st.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

k_values = range(1, 30)
mse_values = []

mse_values = [
    mean_squared_error(Y_test, KNeighborsClassifier(n_neighbors=k).fit(X_train, Y_train).predict(X_test))
    for k in range(1, 20)
]

# Plotting the results
plt.plot(range(1, 20), mse_values, marker='o')
plt.title('KNN Mean Squared Error for different k values')
plt.xlabel('k value')
plt.ylabel('Mean Squared Error')
plt.xticks(range(1, 20))
plt.grid(True)
plt.show()

# %%
k = 7
knn_classifier = KNeighborsClassifier(n_neighbors=k)
# Training the model
knn_classifier.fit(X_train, Y_train)

y_pred = knn_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Confusion matrix
print("Classification Report:")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy: 0.80
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87      6437
#            1       0.59      0.55      0.57      2057
#
#     accuracy                           0.80      8494
#    macro avg       0.73      0.72      0.72      8494
# weighted avg       0.80      0.80      0.80      8494

# %%
cm = confusion_matrix(Y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 16})
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
